# %% [markdown]
# # Vježba 17.07 Spajanje i popravak tablica o edukacijama

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
def apply_iqr_capping(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Primjena cappinga
    # Sve vrijednosti manje od donje granice postaju donja granica
    # Sve vrijednosti veće od gornje granice postaju gornja granica
    capped_series = series.clip(lower=lower_bound, upper=upper_bound)
    return capped_series

# %%
def parse_datum(s):
    for fmt in ('%d.%m.%Y', '%Y-%m-%d', '%m/%d/%Y', '%d-%m-%Y'):
        try:
            return pd.to_datetime(s, format=fmt)
        except:
            continue
    return pd.NaT  # ako nijedan ne uspije

# %% [markdown]
# ### Učitavnje csv datoteka u pandas dataframove

# %%
polaznici=pd.read_csv("../../../datasets/df_polaznici.csv")
tecajevi=pd.read_csv("../../../datasets/df_tecajevi.csv")
upisi=pd.read_csv("../../../datasets/df_upisi.csv")

# %%
upisi
# Out:
#      UpisID  PolaznikID  TecajID Datum_Upisa Status_Upisa
# 0        10      1156.0   5095.0  07/20/2023      Aktivan
# 1        41      1400.0   6202.0  11-10-2023      Završen
# 2       456      1065.0   5091.0  07/10/2024   Na čekanju
# 3       404      1314.0   5033.0  2023-11-12      Završen
# 4       592      1272.0   5090.0  24-02-2022      Aktivan
# ..      ...         ...      ...         ...          ...
# 610     424      1048.0   5047.0  06/13/2024      Aktivan
# 611     533      1119.0   5012.0  09/25/2022      Aktivan
# 612     224      1149.0   5044.0  27-10-2023      Aktivan
# 613      70      1088.0   5084.0  18-05-2024      Aktivan
# 614      16      1064.0      NaN  03-07-2024      Aktivan
#
# [615 rows x 5 columns]

# %%
tecajevi
# Out:
#     TecajID           Naziv_Tecaja    Razina  Trajanje_Sati  Cijena_USD
# 0      5015  Strojno učenje osnove   Srednji           35.6       88.24
# 1      5013      Data Storytelling   Srednji           46.0      182.10
# 2      5082  Strojno učenje osnove   Srednji           26.0       70.64
# 3      5043           Napredni SQL   srednji           31.8      126.97
# 4      5064  Strojno učenje osnove  napredni          -10.0       20.00
# ..      ...                    ...       ...            ...         ...
# 95     5050          Uvod u Python   srednji           34.9      146.22
# 96     5021        Cloud Computing   Srednji           42.3    10000.00
# 97     5086      Data Storytelling   Početni           28.3      180.95
# 98     5085        Cloud Computing   Početni            NaN      193.78
# 99     5054          Uvod u Python   Srednji           26.3       96.36
#
# [100 rows x 5 columns]

# %%
polaznici
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme
# 0          1377             1979            Europa      Španjolski
# 1          1221             1973            Europa       Francuski
# 2          1100             2002            Europa      Španjolski
# 3          1218             2000               NaN       Francuski
# 4          1057             1975     Južna Amerika        Engleski
# ..          ...              ...               ...             ...
# 405        1044             1952               NaN        Engleski
# 406        1126             1991             Azija        Engleski
# 407        1245             2003  Sjeverna Amerika        Engleski
# 408        1186             1971  Sjeverna Amerika      Španjolski
# 409        1035             1991  Sjeverna Amerika        Engleski
#
# [410 rows x 4 columns]

# %% [markdown]
# ### Povezivanje df-ova u jedan

# %%
polaznici_upisi=pd.merge(polaznici,upisi, on="PolaznikID", how="inner")

# %%
polaznici_upisi_tecajevi=pd.merge(polaznici_upisi,tecajevi, on="TecajID", how="inner")

# %%
edu=polaznici_upisi_tecajevi.copy()

# %%
edu
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 0          1377             1979            Europa      Španjolski     495
# 1          1221             1973            Europa       Francuski     168
# 2          1221             1973            Europa       Francuski     449
# 3          1221             1973            Europa       Francuski     335
# 4          1221             1973            Europa       Francuski      30
# ..          ...              ...               ...             ...     ...
# 546        1044             1952               NaN        Engleski      58
# 547        1126             1991             Azija        Engleski     112
# 548        1186             1971  Sjeverna Amerika      Španjolski     398
# 549        1035             1991  Sjeverna Amerika        Engleski     313
# 550        1035             1991  Sjeverna Amerika        Engleski     153
#
#      TecajID Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  \
# 0     5089.0  12-08-2024      Završen         Cloud Computing   Srednji
# 1     5068.0  2022-03-05      Završen   Strojno učenje osnove   Srednji
# 2     5083.0  2024-06-16      Aktivan         Cloud Computing  Napredni
# 3     5025.0  26-09-2022      Aktivan           Uvod u Python   Početni
# 4     5033.0  2023-11-11      Aktivan       Data Storytelling   Početni
# ..       ...         ...          ...                     ...       ...
# 546   5094.0  2022-12-25      Odustao        Excel za analizu   Početni
# 547   5081.0  04/24/2023      Završen  Vizualizacija podataka   početni
# 548   5001.0  03/03/2024   Na čekanju  Vizualizacija podataka   Srednji
# 549   5095.0  03/02/2024      Aktivan           Uvod u Python   Početni
# 550   5007.0  01/31/2022      Aktivan   Strojno učenje osnove   Srednji
#
#      Trajanje_Sati  Cijena_USD
# 0             19.1       20.00
# 1             30.6       81.00
# 2             22.5       61.05
# 3              NaN       66.03
# 4             30.6         NaN
# ..             ...         ...
# 546           31.8      121.47
# 547           31.5      136.03
# 548           40.2      185.49
# 549           42.7      100.04
# 550           20.6       82.92
#
# [551 rows x 12 columns]

# %% [markdown]
# ### Dodavanje novog stupca Starost i brisanje Godina_rodjenja

# %%
edu["Starost"]=2025-edu["Godina_Rodjenja"]

# %%
edu=edu.drop("Godina_Rodjenja",axis=1)

# %%
edu
# Out:
#      PolaznikID            Regija Jezik_Platforme  UpisID  TecajID  \
# 0          1377            Europa      Španjolski     495   5089.0
# 1          1221            Europa       Francuski     168   5068.0
# 2          1221            Europa       Francuski     449   5083.0
# 3          1221            Europa       Francuski     335   5025.0
# 4          1221            Europa       Francuski      30   5033.0
# ..          ...               ...             ...     ...      ...
# 546        1044               NaN        Engleski      58   5094.0
# 547        1126             Azija        Engleski     112   5081.0
# 548        1186  Sjeverna Amerika      Španjolski     398   5001.0
# 549        1035  Sjeverna Amerika        Engleski     313   5095.0
# 550        1035  Sjeverna Amerika        Engleski     153   5007.0
#
#     Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  Trajanje_Sati  \
# 0    12-08-2024      Završen         Cloud Computing   Srednji           19.1
# 1    2022-03-05      Završen   Strojno učenje osnove   Srednji           30.6
# 2    2024-06-16      Aktivan         Cloud Computing  Napredni           22.5
# 3    26-09-2022      Aktivan           Uvod u Python   Početni            NaN
# 4    2023-11-11      Aktivan       Data Storytelling   Početni           30.6
# ..          ...          ...                     ...       ...            ...
# 546  2022-12-25      Odustao        Excel za analizu   Početni           31.8
# 547  04/24/2023      Završen  Vizualizacija podataka   početni           31.5
# 548  03/03/2024   Na čekanju  Vizualizacija podataka   Srednji           40.2
# 549  03/02/2024      Aktivan           Uvod u Python   Početni           42.7
# 550  01/31/2022      Aktivan   Strojno učenje osnove   Srednji           20.6
#
#      Cijena_USD  Starost
# 0         20.00       46
# 1         81.00       52
# 2         61.05       52
# 3         66.03       52
# 4           NaN       52
# ..          ...      ...
# 546      121.47       73
# 547      136.03       34
# 548      185.49       54
# 549      100.04       34
# 550       82.92       34
#
# [551 rows x 12 columns]

# %%
edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PolaznikID       551 non-null    int64
#  1   Regija           522 non-null    object
#  2   Jezik_Platforme  551 non-null    object
#  3   UpisID           551 non-null    int64
#  4   TecajID          551 non-null    float64
#  5   Datum_Upisa      548 non-null    object
#  6   Status_Upisa     551 non-null    object
#  7   Naziv_Tecaja     551 non-null    object
#  8   Razina           551 non-null    object
#  9   Trajanje_Sati    491 non-null    float64
#  10  Cijena_USD       497 non-null    float64
#  11  Starost          551 non-null    int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 51.8+ KB

# %% [markdown]
# ### Provjera i brisanje duplikata

# %%
edu.duplicated().sum()
# Out:
# np.int64(30)

# %%
edu=edu.drop_duplicates()

# %% [markdown]
# ### Provjera i ispravak tipfelera u stringovima

# %%
edu.Regija.value_counts()
# Out:
# Regija
# Europa              158
# Sjeverna Amerika    118
# Azija                83
# Afrika               61
# Južna Amerika        46
# Australija           29
# Name: count, dtype: int64

# %%
edu["Jezik_Platforme"].value_counts()
# Out:
# Jezik_Platforme
# Engleski      272
# Španjolski     54
# Francuski      52
# Njemački       43
# Hrvatski       36
# engleski       26
# španjolski     13
# ENG             8
# hrvatski        6
# francuski       6
# ŠPA             3
# njemački        1
# HRV             1
# Name: count, dtype: int64

# %%
edu["Jezik_Platforme"]=edu["Jezik_Platforme"].str.title()
# Out:
# /tmp/ipykernel_16549/2432011232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu["Jezik_Platforme"]=edu["Jezik_Platforme"].str.title()

# %%
edu["Jezik_Platforme"]=edu["Jezik_Platforme"].replace({"Hrv":"Hrvatski","Špa":"Španjolski","Eng":"Engleski"})
# Out:
# /tmp/ipykernel_16549/734602698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu["Jezik_Platforme"]=edu["Jezik_Platforme"].replace({"Hrv":"Hrvatski","Špa":"Španjolski","Eng":"Engleski"})

# %%
edu["Status_Upisa"].value_counts()
# Out:
# Status_Upisa
# Aktivan       311
# Završen       137
# Odustao        48
# Na čekanju     25
# Name: count, dtype: int64

# %%
edu["Naziv_Tecaja"].value_counts()
# Out:
# Naziv_Tecaja
# Uvod u Python                 83
# Cloud Computing               80
# Vizualizacija podataka        74
# Strojno učenje osnove         70
# Excel za analizu              70
# Statistika za Data Science    53
# Data Storytelling             50
# Napredni SQL                  41
# Name: count, dtype: int64

# %%
edu["Razina"].value_counts()
# Out:
# Razina
# Početni     183
# Srednji     176
# početni      46
# srednji      44
# Napredni     30
# napredni     14
# ADVANCED     13
# BEGINNER     10
# INTERMED      5
# Name: count, dtype: int64

# %%
edu["Razina"]=edu["Razina"].str.title()
edu["Razina"]=edu["Razina"].replace({"Beginner":"Početni","Intermed":"Srednji","Advanced":"Napredni"})
# Out:
# /tmp/ipykernel_16549/3081655996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu["Razina"]=edu["Razina"].str.title()
# /tmp/ipykernel_16549/3081655996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu["Razina"]=edu["Razina"].replace({"Beginner":"Početni","Intermed":"Srednji","Advanced":"Napredni"})

# %%
edu.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Provjera i ispravak brojčanih podataka

# %%
edu.describe()
# Out:
#         PolaznikID      UpisID      TecajID  Trajanje_Sati    Cijena_USD  \
# count   521.000000  521.000000   521.000000     466.000000    470.000000
# mean   1198.416507  302.213052  5051.435701      96.510730    202.978830
# std     112.670406  172.523306    28.347911     798.927847    926.671631
# min    1001.000000    1.000000  5001.000000     -10.000000      0.000000
# 25%    1099.000000  153.000000  5028.000000      22.400000     63.930000
# 50%    1198.000000  304.000000  5051.000000      30.100000    108.740000
# 75%    1294.000000  450.000000  5075.000000      37.600000    136.030000
# max    1400.000000  600.000000  5100.000000    9999.000000  10000.000000
#
#           Starost
# count  521.000000
# mean    47.472169
# std     15.612609
# min     20.000000
# 25%     35.000000
# 50%     48.000000
# 75%     60.000000
# max     75.000000

# %% [markdown]
# ### Čišćenje Outliera

# %%
sns.boxplot(data=edu,x="Trajanje_Sati")
# Out:
# <Axes: xlabel='Trajanje_Sati'>

# %%
edu2=edu.copy()

# %%
edu2["Trajanje_Sati"].sort_values(ascending=False)
# Out:
# 284    9999.0
# 444    9999.0
# 193    9999.0
# 523     500.0
# 120     500.0
#         ...
# 505       NaN
# 522       NaN
# 531       NaN
# 539       NaN
# 545       NaN
# Name: Trajanje_Sati, Length: 521, dtype: float64

# %%
edu.loc[edu["Trajanje_Sati"]>499,"Trajanje_Sati"]=np.nan

# %%
edu["Trajanje_Sati"]=edu["Trajanje_Sati"].abs()
# Out:
# /tmp/ipykernel_16549/2493030833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu["Trajanje_Sati"]=edu["Trajanje_Sati"].abs()

# %%
sns.boxplot(data=edu,x="Trajanje_Sati")
# Out:
# <Axes: xlabel='Trajanje_Sati'>

# %%
sns.boxplot(data=edu, x="Cijena_USD")
# Out:
# <Axes: xlabel='Cijena_USD'>

# %%
edu3=edu.copy()
edu3["Cijena_USD"].sort_values(ascending=False).head(20)
# Out:
# 335    10000.00
# 473    10000.00
# 369    10000.00
# 106    10000.00
# 354     2000.00
# 139     2000.00
# 478     2000.00
# 234     2000.00
# 73       224.47
# 348      224.47
# 411      224.47
# 95       224.47
# 129      224.47
# 189      196.06
# 361      196.06
# 215      193.78
# 204      193.78
# 247      193.78
# 343      193.78
# 531      193.78
# Name: Cijena_USD, dtype: float64

# %%
edu.loc[edu["Cijena_USD"]>230,"Cijena_USD"]=pd.NA

# %%
sns.boxplot(data=edu, x="Cijena_USD")
# Out:
# <Axes: xlabel='Cijena_USD'>

# %%
sns.boxplot(data=edu, x="Starost")
# Out:
# <Axes: xlabel='Starost'>

# %% [markdown]
# ### Provjera povezanosti brojčanih podataka

# %%
edu.corr(numeric_only=True)
# Out:
#                PolaznikID    UpisID   TecajID  Trajanje_Sati  Cijena_USD  \
# PolaznikID       1.000000  0.005276 -0.044840      -0.009648    0.022362
# UpisID           0.005276  1.000000 -0.094399      -0.004729    0.048438
# TecajID         -0.044840 -0.094399  1.000000       0.073449   -0.058907
# Trajanje_Sati   -0.009648 -0.004729  0.073449       1.000000    0.000215
# Cijena_USD       0.022362  0.048438 -0.058907       0.000215    1.000000
# Starost         -0.086336 -0.035244  0.027534       0.022665   -0.032474
#
#                 Starost
# PolaznikID    -0.086336
# UpisID        -0.035244
# TecajID        0.027534
# Trajanje_Sati  0.022665
# Cijena_USD    -0.032474
# Starost        1.000000

# %%
sns.pairplot(edu)

# %%
sns.scatterplot(data=edu, x="TecajID", y="Cijena_USD", hue="Razina")
# Out:
# <Axes: xlabel='TecajID', ylabel='Cijena_USD'>

# %% [markdown]
# ### Primjećene slabe povezanosti što ukazuje na dodatne outlajere unutar podgrupa podataka

# %%
sns.boxplot(data=edu, x="Razina", y="Trajanje_Sati")
plt.title("Trajanje tečaja po razini")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po razini')

# %%
sns.boxplot(data=edu, x="Razina", y="Cijena_USD")
plt.title("Cijena tečaja po razini")
# Out:
# Text(0.5, 1.0, 'Cijena tečaja po razini')

# %%
sns.boxplot(data=edu, x="Status_Upisa", y="Trajanje_Sati")
plt.title("Trajanje tečaja po statusu upisa")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po statusu upisa')

# %%
sns.boxplot(data=edu, x="Status_Upisa", y="Cijena_USD")
plt.title("Cijena tečaja po statusu upisa")
# Out:
# Text(0.5, 1.0, 'Cijena tečaja po statusu upisa')

# %%
sns.boxplot(data=edu, x="Regija", y="Trajanje_Sati")
plt.title("Trajanje tečaja po regiji")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po regiji')

# %%
sns.boxplot(data=edu, x="Regija", y="Cijena_USD")
plt.title("Trajanje tečaja po regiji")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po regiji')

# %% [markdown]
# ### Prema ovim boxplotovima nemože se baš nešto zaključiti osim da postoje outlieri koji su možda i realni s obzirom na staus upisa. Za nekakve ozbiljnije zaključke bi trebalo analizirati samo status upisa završen i u njemu je vidljivo da ima outliere.

# %%
edu_zavrseni = edu[edu["Status_Upisa"] == "Završen"]

# %%
edu_zavrseni
# Out:
#      PolaznikID            Regija Jezik_Platforme  UpisID  TecajID  \
# 0          1377            Europa      Španjolski     495   5089.0
# 1          1221            Europa       Francuski     168   5068.0
# 5          1221            Europa       Francuski      27   5087.0
# 7          1100            Europa      Španjolski      64   5044.0
# 9          1057     Južna Amerika        Engleski      42   5081.0
# ..          ...               ...             ...     ...      ...
# 522        1180     Južna Amerika        Engleski     388   5077.0
# 526        1358            Europa       Francuski     113   5091.0
# 527        1358            Europa       Francuski      46   5082.0
# 531        1334  Sjeverna Amerika        Engleski     485   5085.0
# 547        1126             Azija        Engleski     112   5081.0
#
#     Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  Trajanje_Sati  \
# 0    12-08-2024      Završen         Cloud Computing   Srednji           19.1
# 1    2022-03-05      Završen   Strojno učenje osnove   Srednji           30.6
# 5    11/08/2022      Završen           Uvod u Python   Početni            NaN
# 7    07-06-2023      Završen   Strojno učenje osnove  Napredni           36.4
# 9    26-09-2024      Završen  Vizualizacija podataka   Početni           31.5
# ..          ...          ...                     ...       ...            ...
# 522  10/22/2022      Završen   Strojno učenje osnove  Napredni            NaN
# 526  21-02-2022      Završen  Vizualizacija podataka  Napredni           39.5
# 527  07/05/2022      Završen   Strojno učenje osnove   Srednji           26.0
# 531  10-01-2024      Završen         Cloud Computing   Početni            NaN
# 547  04/24/2023      Završen  Vizualizacija podataka   Početni           31.5
#
#      Cijena_USD  Starost
# 0         20.00       46
# 1         81.00       52
# 5          5.00       52
# 7        144.73       23
# 9        136.03       50
# ..          ...      ...
# 522       23.00       47
# 526       53.62       72
# 527       70.64       72
# 531      193.78       24
# 547      136.03       34
#
# [137 rows x 12 columns]

# %%
edu_zavrseni.isna().sum()
# Out:
# PolaznikID          0
# Regija              5
# Jezik_Platforme     0
# UpisID              0
# TecajID             0
# Datum_Upisa         0
# Status_Upisa        0
# Naziv_Tecaja        0
# Razina              0
# Trajanje_Sati      17
# Cijena_USD         13
# Starost             0
# dtype: int64

# %%
edu_zavrseni.describe()
# Out:
#         PolaznikID      UpisID      TecajID  Trajanje_Sati  Cijena_USD  \
# count   137.000000  137.000000   137.000000     120.000000  124.000000
# mean   1204.591241  298.167883  5055.065693      29.982500  103.418710
# std     112.203174  184.166987    27.855511      11.939685   52.926748
# min    1001.000000    4.000000  5001.000000       0.000000    0.000000
# 25%    1115.000000  129.000000  5032.000000      22.325000   65.505000
# 50%    1205.000000  295.000000  5057.000000      31.000000  114.205000
# 75%    1301.000000  462.000000  5079.000000      38.000000  136.030000
# max    1398.000000  599.000000  5100.000000      59.200000  224.470000
#
#           Starost
# count  137.000000
# mean    47.072993
# std     16.303029
# min     20.000000
# 25%     34.000000
# 50%     44.000000
# 75%     60.000000
# max     75.000000

# %% [markdown]
# ### Možemo zaklučiti da su neki tečajevi završeni 0 h što bi značilo da nisu ni pohađali tečaj njih možemo smatrati outlierima. Također cijena 0 bi značilo da nisu plaćali tečaj

# %%
edu_zavrseni2=edu_zavrseni.copy()

# %%
edu_zavrseni2.sort_values(by='Trajanje_Sati').head(20)
# Out:
#      PolaznikID            Regija Jezik_Platforme  UpisID  TecajID  \
# 52         1315            Afrika        Engleski     445   5065.0
# 178        1234            Afrika       Francuski     295   5065.0
# 384        1141            Europa        Engleski      72   5065.0
# 342        1069     Južna Amerika        Engleski     451   5076.0
# 349        1178             Azija        Engleski     262   5076.0
# 359        1362            Europa        Engleski     228   5012.0
# 192        1142  Sjeverna Amerika        Engleski     339   5064.0
# 45         1190            Europa       Francuski     594   5064.0
# 481        1381            Europa      Španjolski     222   5064.0
# 317        1101             Azija        Engleski     586   5064.0
# 249        1063  Sjeverna Amerika        Engleski      88   5022.0
# 378        1042             Azija      Španjolski      40   5045.0
# 390        1043             Azija       Francuski      71   5046.0
# 200        1323            Europa        Njemački     450   5046.0
# 295        1228            Afrika        Engleski     469   5046.0
# 489        1361            Europa       Francuski     119   5046.0
# 310        1123             Azija        Njemački     325   5028.0
# 0          1377            Europa      Španjolski     495   5089.0
# 361        1093            Europa        Engleski     118   5056.0
# 70         1338            Afrika        Engleski     126   5053.0
#
#     Datum_Upisa Status_Upisa                Naziv_Tecaja    Razina  \
# 52   04/11/2024      Završen            Excel za analizu   Početni
# 178  03/26/2022      Završen            Excel za analizu   Početni
# 384  2023-09-11      Završen            Excel za analizu   Početni
# 342  29-04-2023      Završen                Napredni SQL   Početni
# 349  2024-06-13      Završen                Napredni SQL   Početni
# 359  06/17/2022      Završen      Vizualizacija podataka   Srednji
# 192  2024-06-15      Završen       Strojno učenje osnove  Napredni
# 45   12-04-2023      Završen       Strojno učenje osnove  Napredni
# 481  11/19/2022      Završen       Strojno učenje osnove  Napredni
# 317  30-09-2024      Završen       Strojno učenje osnove  Napredni
# 249  18-07-2022      Završen  Statistika za Data Science   Srednji
# 378  12/28/2024      Završen             Cloud Computing   Početni
# 390  05/28/2023      Završen            Excel za analizu   Srednji
# 200  2022-09-16      Završen            Excel za analizu   Srednji
# 295  08-08-2023      Završen            Excel za analizu   Srednji
# 489  2024-04-16      Završen            Excel za analizu   Srednji
# 310  2024-01-12      Završen  Statistika za Data Science   Početni
# 0    12-08-2024      Završen             Cloud Computing   Srednji
# 361  11-09-2023      Završen                Napredni SQL  Napredni
# 70   08-05-2024      Završen               Uvod u Python   Srednji
#
#      Trajanje_Sati  Cijena_USD  Starost
# 52             0.0      116.65       28
# 178            0.0      116.65       74
# 384            0.0      116.65       41
# 342            1.0      111.09       59
# 349            1.0      111.09       61
# 359            9.8      179.00       28
# 192           10.0       20.00       32
# 45            10.0       20.00       31
# 481           10.0       20.00       25
# 317           10.0       20.00       52
# 249           13.6       52.81       69
# 378           14.6         NaN       21
# 390           16.1      134.11       24
# 200           16.1      134.11       41
# 295           16.1      134.11       24
# 489           16.1      134.11       55
# 310           17.9      122.54       41
# 0             19.1       20.00       46
# 361           19.8      196.06       53
# 70            20.1      123.02       40

# %%
edu_zavrseni2.sort_values(by='Cijena_USD').head(20)
# Out:
#      PolaznikID            Regija Jezik_Platforme  UpisID  TecajID  \
# 179        1046            Europa        Engleski     235   5037.0
# 293        1163  Sjeverna Amerika        Engleski     562   5037.0
# 336        1340               NaN      Španjolski      29   5037.0
# 23         1096            Europa        Engleski     583   5005.0
# 232        1301        Australija        Hrvatski     139   5005.0
# 5          1221            Europa       Francuski      27   5087.0
# 132        1354             Azija        Engleski      43   5035.0
# 142        1271  Sjeverna Amerika      Španjolski      91   5066.0
# 192        1142  Sjeverna Amerika        Engleski     339   5064.0
# 317        1101             Azija        Engleski     586   5064.0
# 45         1190            Europa       Francuski     594   5064.0
# 0          1377            Europa      Španjolski     495   5089.0
# 481        1381            Europa      Španjolski     222   5064.0
# 522        1180     Južna Amerika        Engleski     388   5077.0
# 357        1287             Azija        Engleski     285   5077.0
# 155        1160     Južna Amerika       Francuski     129   5075.0
# 98         1227            Europa       Francuski     599   5075.0
# 262        1110  Sjeverna Amerika        Engleski       6   5075.0
# 201        1090            Europa        Njemački     480   5075.0
# 199        1168            Europa        Engleski     535   5016.0
#
#     Datum_Upisa Status_Upisa                Naziv_Tecaja    Razina  \
# 179  08/16/2022      Završen            Excel za analizu   Srednji
# 293  02/03/2023      Završen            Excel za analizu   Srednji
# 336  25-10-2024      Završen            Excel za analizu   Srednji
# 23   05-09-2023      Završen  Statistika za Data Science   Početni
# 232  2024-07-20      Završen  Statistika za Data Science   Početni
# 5    11/08/2022      Završen               Uvod u Python   Početni
# 132  15-03-2022      Završen                Napredni SQL  Napredni
# 142  18-01-2024      Završen           Data Storytelling   Srednji
# 192  2024-06-15      Završen       Strojno učenje osnove  Napredni
# 317  30-09-2024      Završen       Strojno učenje osnove  Napredni
# 45   12-04-2023      Završen       Strojno učenje osnove  Napredni
# 0    12-08-2024      Završen             Cloud Computing   Srednji
# 481  11/19/2022      Završen       Strojno učenje osnove  Napredni
# 522  10/22/2022      Završen       Strojno učenje osnove  Napredni
# 357  09/13/2023      Završen       Strojno učenje osnove  Napredni
# 155  04/15/2024      Završen      Vizualizacija podataka   Srednji
# 98   2023-05-12      Završen      Vizualizacija podataka   Srednji
# 262  10/24/2022      Završen      Vizualizacija podataka   Srednji
# 201  12/23/2022      Završen      Vizualizacija podataka   Srednji
# 199  08/06/2022      Završen  Statistika za Data Science  Napredni
#
#      Trajanje_Sati  Cijena_USD  Starost
# 179            NaN        0.00       25
# 293            NaN        0.00       50
# 336            NaN        0.00       36
# 23             NaN        0.01       60
# 232            NaN        0.01       26
# 5              NaN        5.00       52
# 132           26.0       20.00       60
# 142           20.9       20.00       54
# 192           10.0       20.00       32
# 317           10.0       20.00       52
# 45            10.0       20.00       31
# 0             19.1       20.00       46
# 481           10.0       20.00       25
# 522            NaN       23.00       47
# 357            NaN       23.00       56
# 155           59.2       28.56       67
# 98            59.2       28.56       35
# 262           59.2       28.56       51
# 201           59.2       28.56       61
# 199           21.9       31.93       37

# %% [markdown]
# ### Nakon sortiranja min vrijednosti sumljive su cijene 23 i niže, a trajanja 10 i niže

# %%
edu_zavrseni.loc[edu["Trajanje_Sati"]<=10,"Trajanje_Sati"]=np.nan
edu_zavrseni.loc[edu["Cijena_USD"]<=23,"Cijena_USD"]=np.nan

# %%
edu_zavrseni.describe()
# Out:
#         PolaznikID      UpisID      TecajID  Trajanje_Sati  Cijena_USD  \
# count   137.000000  137.000000   137.000000     110.000000  109.000000
# mean   1204.591241  298.167883  5055.065693      32.237273  115.898165
# std     112.203174  184.166987    27.855511       9.589548   43.330442
# min    1001.000000    4.000000  5001.000000      13.600000   28.560000
# 25%    1115.000000  129.000000  5032.000000      25.775000   82.700000
# 50%    1205.000000  295.000000  5057.000000      31.500000  121.470000
# 75%    1301.000000  462.000000  5079.000000      38.000000  139.850000
# max    1398.000000  599.000000  5100.000000      59.200000  224.470000
#
#           Starost
# count  137.000000
# mean    47.072993
# std     16.303029
# min     20.000000
# 25%     34.000000
# 50%     44.000000
# 75%     60.000000
# max     75.000000

# %%
sns.boxplot(data=edu_zavrseni, x="Razina", y="Trajanje_Sati")
plt.title("Trajanje tečaja po razini")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po razini')

# %%
edu_zavrseni = edu_zavrseni.drop(columns=["PolaznikID", "UpisID"])
edu_zavrseni.corr(numeric_only=True)
# Out:
#                 TecajID  Trajanje_Sati  Cijena_USD   Starost
# TecajID        1.000000       0.170917   -0.080329  0.145258
# Trajanje_Sati  0.170917       1.000000   -0.272992  0.041419
# Cijena_USD    -0.080329      -0.272992    1.000000 -0.151945
# Starost        0.145258       0.041419   -0.151945  1.000000

# %%
sns.boxplot(data=edu_zavrseni, x="Razina", y="Cijena_USD")
plt.title("Cijena tečaja po razini")
# Out:
# Text(0.5, 1.0, 'Cijena tečaja po razini')

# %%
sns.boxplot(data=edu_zavrseni, x="Regija", y="Trajanje_Sati")
plt.title("Trajanje tečaja po regiji")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po regiji')

# %%
sns.boxplot(data=edu_zavrseni, x="Regija", y="Cijena_USD")
plt.title("Trajanje tečaja po regiji")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po regiji')

# %%
sns.boxplot(data=edu_zavrseni, x="Jezik_Platforme", y="Cijena_USD")
plt.title("Trajanje tečaja po jeziku")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po jeziku')

# %%
edu_zavrseni3=edu_zavrseni.copy()
label_enc=LabelEncoder()
edu_zavrseni3.Regija=label_enc.fit_transform(edu_zavrseni3.Regija)
edu_zavrseni3["Jezik_Platforme"]=label_enc.fit_transform(edu_zavrseni3["Jezik_Platforme"])
edu_zavrseni3["Razina"]=label_enc.fit_transform(edu_zavrseni3["Razina"])
edu_zavrseni3["Naziv_Tecaja"]=label_enc.fit_transform(edu_zavrseni3["Naziv_Tecaja"])

# %%
edu_zavrseni3.corr(numeric_only=True)
# Out:
#                    Regija  Jezik_Platforme   TecajID  Naziv_Tecaja    Razina  \
# Regija           1.000000        -0.004822 -0.024648     -0.082163 -0.025573
# Jezik_Platforme -0.004822         1.000000  0.074649      0.002244  0.107008
# TecajID         -0.024648         0.074649  1.000000      0.130429 -0.171064
# Naziv_Tecaja    -0.082163         0.002244  0.130429      1.000000 -0.200509
# Razina          -0.025573         0.107008 -0.171064     -0.200509  1.000000
# Trajanje_Sati    0.107698         0.004906  0.170917      0.278114  0.052429
# Cijena_USD      -0.014556        -0.009418 -0.080329     -0.441976 -0.003827
# Starost          0.104276        -0.056295  0.145258     -0.010370 -0.087548
#
#                  Trajanje_Sati  Cijena_USD   Starost
# Regija                0.107698   -0.014556  0.104276
# Jezik_Platforme       0.004906   -0.009418 -0.056295
# TecajID               0.170917   -0.080329  0.145258
# Naziv_Tecaja          0.278114   -0.441976 -0.010370
# Razina                0.052429   -0.003827 -0.087548
# Trajanje_Sati         1.000000   -0.272992  0.041419
# Cijena_USD           -0.272992    1.000000 -0.151945
# Starost               0.041419   -0.151945  1.000000

# %%
sns.heatmap(edu_zavrseni3.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# # Zaključak
# ### Najveću povezanost pokazuju naziv tečaja i trajanje tečaja.
# ### Za dodatne zaključke potrebno je dodatno istražiti i popraviti subgrupe i nakon toga se mogu na osnovu zaključaka popraviti Nan vrijednosti

# %%
sns.boxplot(data=edu_zavrseni3, x="Naziv_Tecaja", y="Trajanje_Sati")
plt.title("Trajanje tečaja po nazivu tecaja")
# Out:
# Text(0.5, 1.0, 'Trajanje tečaja po nazivu tecaja')

# %%
sns.barplot(data=edu_zavrseni3, x="Naziv_Tecaja", y="Trajanje_Sati", estimator="mean", errorbar="sd")
plt.title("Prosječno trajanje po nazivu tečaja")
# Out:
# Text(0.5, 1.0, 'Prosječno trajanje po nazivu tečaja')
