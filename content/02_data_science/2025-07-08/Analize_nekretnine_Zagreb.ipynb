# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nekretnine = pd.read_csv("../../../datasets/nekretnine_zagreb.csv")

# %%
nekretnine.head(10)
# Out:
#    Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0           0   Trešnjevka              Stan           79.0          1
# 1           1  Novi Zagreb              Stan           69.0          5
# 2           2  Novi Zagreb              Stan           51.0          5
# 3           3     Maksimir              Stan           57.0          4
# 4           4   Trešnjevka  Poslovni Prostor           74.0          2
# 5           5       Centar              Stan           67.0          2
# 6           6       Centar              Stan            NaN         15
# 7           7       Centar  Poslovni Prostor           89.0          3
# 8           8          NaN              Stan            NaN          5
# 9           9     Maksimir              Stan           67.0          5
#
#    Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# 0       1953.028278     70000.0          2023-01-01
# 1       1967.566714    110000.0          2023-01-02
# ...

# %%
nekretnine.isna().sum()
# Out:
# Unnamed: 0              0
# Kvart                  10
# Tip_Nekretnine          0
# Kvadratura_m2           8
# Broj_Soba               0
# Godina_Izgradnje        7
# Cijena_EUR              0
# Datum_Objave_Oglasa    15
# dtype: int64

# %%
nekretnine['Datum_Objave_Oglasa'] = nekretnine['Datum_Objave_Oglasa'].ffill()

# %%
sns.pairplot(nekretnine)

# %%
nekretnine['Kvart'] = nekretnine['Kvart'].ffill()

# %%
nekretnine['Kvadratura_m2'] = nekretnine['Kvadratura_m2'].ffill()

# %%
nekretnine['Godina_Izgradnje'] = nekretnine['Godina_Izgradnje'].ffill()

# %%
nekretnine.isna().sum()
# Out:
# Unnamed: 0             0
# Kvart                  0
# Tip_Nekretnine         0
# Kvadratura_m2          0
# Broj_Soba              0
# Godina_Izgradnje       0
# Cijena_EUR             0
# Datum_Objave_Oglasa    0
# dtype: int64

# %%
nekretnine
# Out:
#     Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0            0   Trešnjevka              Stan           79.0          1
# 1            1  Novi Zagreb              Stan           69.0          5
# 2            2  Novi Zagreb              Stan           51.0          5
# 3            3     Maksimir              Stan           57.0          4
# 4            4   Trešnjevka  Poslovni Prostor           74.0          2
# ..         ...          ...               ...            ...        ...
# 95          95     Maksimir              Stan           73.0          5
# 96          96   Trešnjevka              Stan           78.0          5
# 97          97     Maksimir              Kuća           80.0          2
# 98          98       Centar              Stan           76.0          5
# 99          99   Trešnjevka              Stan           51.0          1
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# ...

# %%
nekretnine['Kvadratura_m2'].mean()
# Out:
# np.float64(67.65)
