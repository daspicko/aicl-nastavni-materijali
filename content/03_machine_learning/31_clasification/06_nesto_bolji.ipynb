# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn import datasets
from sklearn import model_selection
from sklearn import linear_model

# %%
diabetes = datasets.load_diabetes()

linreg = linear_model.LinearRegression()
scores=[]
ss = model_selection.ShuffleSplit(test_size=0.25)
scores = model_selection.cross_val_score(linreg, diabetes.data, diabetes.target, cv=ss)

df = pd.DataFrame({'RMSE': scores})
df.index.name = 'Repeat'
display(df.T)
ax = plt.figure(figsize=(4, 3)).gca()
sns.swarmplot(y='RMSE', x='Repeat', data=df, ax=ax)
# Out:
# Repeat         0         1         2         3         4         5         6  \
# RMSE    0.508961  0.495249  0.562881  0.440248  0.510308  0.562086  0.507783
#
# Repeat        7         8         9
# RMSE    0.48169  0.461106  0.439155
# <Axes: xlabel='Repeat', ylabel='RMSE'>
