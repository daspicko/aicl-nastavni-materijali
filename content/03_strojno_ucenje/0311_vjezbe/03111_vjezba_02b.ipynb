# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, ShuffleSplit

# %%
musk = pd.read_csv("musk1.csv", low_memory=False)
musk.head()
# Out:
#   Molecule_name    F1     F2    F3    F4     F5    F6     F7    F8     F9  \
# 0     MUSK-jf59  47.0 -110.0 -28.0  31.0 -117.0 -84.0   52.0  -2.0   24.0
# 1     MUSK-jf59   9.0 -114.0 -21.0  26.0 -117.0 -13.0 -166.0  47.0 -221.0
# 2     MUSK-jf59  49.0  -98.0 -26.0  29.0 -117.0 -83.0   66.0 -10.0   44.0
# 3     MUSK-jf59  52.0 -110.0 -21.0  25.0 -117.0  61.0 -161.0  73.0 -218.0
# 4     MUSK-jf59  23.0 -113.0 -21.0  35.0 -117.0  80.0 -161.0  66.0 -216.0
#
#    ...   F158   F159   F160   F161   F162   F163   F164   F165   F166   Class
# 0  ... -209.0 -206.0  -13.0    0.0   29.0   45.0  -44.0   -5.0   -8.0       1
# 1  ...  -51.0   24.0  -30.0  -58.0  -17.0  119.0  -28.0  -28.0  112.0       1
# 2  ... -212.0 -210.0  -13.0    5.0   21.0   48.0  -45.0  -13.0  -12.0       1
# 3  ...   14.0  -26.0  -30.0   12.0    8.0   85.0  -52.0  -60.0  -29.0       1
# 4  ...   34.0   36.0  -31.0  -60.0    2.0   96.0  -31.0   -9.0   90.0       1
#
# [5 rows x 168 columns]

# %%
musk.Class.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n6/jl1ksgl501b4z5wbv6r1g9yc0000gp/T/ipykernel_55259/2448304438.py in ?()
# ----> 1 musk.Class.unique()
#
# ~/workspace/education-ai/ai-centar-lipik/.venv/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Class'

# %% [markdown]
# Postoji problem u nazivu varijable, ne mogu točno odrediti koji pa ću koristiti columns.

# %%
display(musk.describe())
display("Unikatne vrijednosti Class stupca", musk[musk.columns[-1]].unique())
# Out:
#                F1          F2          F3          F4          F5          F6  \
# count  476.000000  476.000000  476.000000  476.000000  476.000000  476.000000
# mean    38.731092 -120.142857  -79.243697   15.903361 -112.298319   -9.760504
# std     18.087948   88.313464   69.172519   75.515959   28.704947   92.025496
# min     -9.000000 -199.000000 -166.000000 -115.000000 -117.000000 -184.000000
# 25%     31.000000 -193.000000 -144.000000  -53.000000 -117.000000  -89.000000
# 50%     42.000000 -144.500000 -108.000000   28.000000 -117.000000   11.000000
# 75%     50.000000 -101.000000  -21.000000   38.000000 -117.000000   70.250000
# max    130.000000   98.000000   83.000000  157.000000  238.000000  200.000000
#
#                F7          F8          F9         F10  ...        F158  \
# count  476.000000  476.000000  476.000000  476.000000  ...  476.000000
# mean   -16.628151    7.762605  -91.048319  -76.077731  ... -204.405462
# std    106.560891   75.786461   96.321303   72.467693  ...   89.566426
# min   -170.000000 -231.000000 -242.000000 -284.000000  ... -324.000000
# 25%   -159.000000   -9.250000 -215.000000 -118.250000  ... -264.000000
# 50%     41.000000   18.000000  -41.000000  -73.500000  ... -236.000000
# 75%     51.000000   57.000000  -30.000000  -28.000000  ... -154.750000
# max    214.000000  188.000000  135.000000  218.000000  ...   72.000000
#
#              F159        F160        F161        F162        F163        F164  \
# count  476.000000  476.000000  476.000000  476.000000  476.000000  476.000000
# mean  -108.262605  -25.231092   37.428571   79.752101   85.363445  -34.128151
# std    121.794583   65.588295   87.315888   49.269244   47.487575   16.019277
# min   -217.000000 -135.000000 -126.000000  -78.000000   35.000000 -132.000000
# 25%   -208.000000  -91.000000  -39.250000   33.000000   54.000000  -42.250000
# 50%   -189.500000  -15.000000   31.500000   84.000000   69.000000  -36.000000
# 75%     30.000000   22.000000  128.000000  119.000000   99.000000  -28.000000
# max    173.000000  185.000000  253.000000  291.000000  302.000000   24.000000
#
#              F165        F166       Class
# count  476.000000  476.000000  476.000000
# mean   -26.241597   33.714286    0.434874
# std     58.009205   54.189087    0.496262
# min   -258.000000  -72.000000    0.000000
# 25%    -28.000000  -12.000000    0.000000
# 50%    -11.000000   35.000000    0.000000
# 75%      7.000000   74.000000    1.000000
# max     82.000000  235.000000    1.000000
#
# [8 rows x 167 columns]
# 'Unikatne vrijednosti Class stupca'
# array([1, 0])

# %% [markdown]
# Prema opisu dataseta i analizom dataseta možemo zaključiti da je target varijabla "Class" koja govori da li se molekula lijeka uspjela vezati na protein. Provjeravamo dataset za za prazne vrijednosti.

# %%
musk.isnull().values.any()
# Out:
# np.False_

# %% [markdown]
# U datasetu ne postoje vrijednosti koje nedostaju.

# %%
target = musk[musk.columns[-1]]
features_num = musk.select_dtypes(include=[np.number])
features = features_num.drop(columns=musk.columns[-1]).select_dtypes(include=[np.number])
features.head()
# Out:
#      F1     F2    F3    F4     F5    F6     F7    F8     F9    F10  ...  \
# 0  47.0 -110.0 -28.0  31.0 -117.0 -84.0   52.0  -2.0   24.0  -60.0  ...
# 1   9.0 -114.0 -21.0  26.0 -117.0 -13.0 -166.0  47.0 -221.0  -48.0  ...
# 2  49.0  -98.0 -26.0  29.0 -117.0 -83.0   66.0 -10.0   44.0 -114.0  ...
# 3  52.0 -110.0 -21.0  25.0 -117.0  61.0 -161.0  73.0 -218.0   28.0  ...
# 4  23.0 -113.0 -21.0  35.0 -117.0  80.0 -161.0  66.0 -216.0   28.0  ...
#
#     F157   F158   F159  F160  F161  F162   F163  F164  F165   F166
# 0 -230.0 -209.0 -206.0 -13.0   0.0  29.0   45.0 -44.0  -5.0   -8.0
# 1 -238.0  -51.0   24.0 -30.0 -58.0 -17.0  119.0 -28.0 -28.0  112.0
# 2 -236.0 -212.0 -210.0 -13.0   5.0  21.0   48.0 -45.0 -13.0  -12.0
# 3 -240.0   14.0  -26.0 -30.0  12.0   8.0   85.0 -52.0 -60.0  -29.0
# 4 -214.0   34.0   36.0 -31.0 -60.0   2.0   96.0 -31.0  -9.0   90.0
#
# [5 rows x 166 columns]

# %%
ss = ShuffleSplit(test_size=0.2)
dtc = DecisionTreeClassifier()
logr = LogisticRegression(solver='saga', max_iter=10000)

scores_dtc = cross_val_score(dtc, features, target, cv=ss, scoring='roc_auc')
scores_logr = cross_val_score(logr, features, target, cv=ss, scoring='roc_auc')

# %%
print('ROC AUC DTC', scores_dtc)
print('ROC AUC LogR', scores_logr)
# Out:
# ROC AUC DTC [0.72091503 0.77206208 0.71164021 0.64444444 0.83391304 0.73957856
#  0.78478261 0.71710812 0.78879892 0.85476086]
# ROC AUC LogR [0.8833042  0.90785432 0.93525499 0.93458393 0.94179894 0.894287
#  0.91652174 0.95614416 0.93658537 0.92676768]

# %%
mean_dtc = np.mean(np.asarray(scores_dtc))
mean_logr = np.mean(np.asarray(scores_logr))

# %%
print('Mean DTC', mean_dtc)
print('Mean LogR', mean_logr)
# Out:
# Mean DTC 0.7568003887055851
# Mean LogR 0.9233102324265184

# %% [markdown]
# Bolji model je logr za koji je korišten algoritam Logističke regresije.
