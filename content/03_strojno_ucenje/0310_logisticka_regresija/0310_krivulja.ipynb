# %%
import matplotlib.pyplot as plt

# %%
def helper(ax,x,y,x_name,y_name):
  ax.plot(x,y, 'r--o')
  ax.set_xlabel(x_name)
  ax.set_ylabel(y_name)

fig, (ax0, ax1) = plt.subplots(1,2, figsize=(9,3))
helper(ax0, probs, log_odds, 'vjerojatnost', 'log-izgledi')
helper(ax1, log_odds, probs, 'log-izgledi', 'vjerojatnost')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4   ax.set_ylabel(y_name)
#       6 fig, (ax0, ax1) = plt.subplots(1,2, figsize=(9,3))
# ----> 7 helper(ax0, probs, log_odds, 'vjerojatnost', 'log-izgledi')
#       8 helper(ax1, log_odds, probs, 'log-izgledi', 'vjerojatnost')
#
# NameError: name 'probs' is not defined
