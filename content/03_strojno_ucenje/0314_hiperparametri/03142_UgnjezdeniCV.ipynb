# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from sklearn import neighbors
from sklearn.model_selection import GridSearchCV
from sklearn import datasets

# %%
iris = datasets.load_iris()
diabetes = datasets.load_diabetes()
digits = datasets.load_digits()

# %%
knn = neighbors.KNeighborsClassifier()
print(" ".join(knn.get_params().keys()))
# Out:
# algorithm leaf_size metric metric_params n_jobs n_neighbors p weights

# %%
param_grid = {
    'n_neighbors': np.arange(1, 11),
    'weights': ['uniform', 'distance'],
    'p': [1, 2, 4, 8, 16]
}
knn = neighbors.KNeighborsClassifier()
grid_model = GridSearchCV(knn, return_train_score=True, param_grid=param_grid, cv=3)
# %timeit -r1 grid_model.fit(iris.data, iris.target)
# Out:
# 312 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
