# %% [markdown]
# # Normalizacija i standardizacija
#
# ### Normalizacija
#
# Process uzimanja različitih mjerenja i njihoog stavljanja na izravnu usporedivu osnovu
#
# ### Standardizacija
#
# Poseban oblik normalizacije.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import explained_variance_score
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# 1D standardization
# place evenly spaced values in a dataframe
xs = np.linspace(-5, 10, 20)
df = pd.DataFrame(xs, columns=['x'])
# center ( - mean) and scale (/ std)
df['std-ized'] = (df.x - df.x.mean()) / df.x.std()
# show original and new data; compute statistics
fig, ax = plt.subplots(1, 1, figsize=(3, 3))
sns.stripplot(data=df)
display(df.describe().loc[['mean', 'std']])
# Out:
#              x      std-ized
# mean  2.500000  4.440892e-17
# std   4.670589  1.000000e+00

# %%
xs = np.linspace(-5, 10, 20)
ys = 3 * xs + 2 * np.random.uniform(20, 40, 20)
df = pd.DataFrame({'x': xs, 'y': ys})
df_standardized = (df - df.mean()) / df.std()
display(df_standardized.describe().loc[['mean', 'std']])
# Out:
#                  x             y
# mean  4.440892e-17  3.219647e-16
# std   1.000000e+00  1.000000e+00

# %%
fig, ax = plt.subplots(2, 2, figsize=(5, 5))
ax[0,0].plot(df.x, df.y, '.')
ax[0,1].plot(df_standardized.x, df_standardized.y, '.')
ax[0,0].set_ylabel('"Natural" Scale')
ax[1,0].plot(df.x, df.y, '.')
ax[1,1].plot(df_standardized.x, df_standardized.y, '.')
ax[1,0].axis([-10, 50, -10, 50])
ax[1,1].axis([-10, 50, -10, 50])
ax[1,0].set_ylabel('Fixed/Shared Scale')
ax[1,0].set_xlabel('Original Data')
ax[1,1].set_xlabel('Standardized Data')
# Out:
# Text(0.5, 0, 'Standardized Data')

# %%
train_xs, test_xs = train_test_split(xs.reshape(-1, 1), test_size=0.5)
scaler = StandardScaler()
scaler.fit(train_xs)
train_xs_standardized = scaler.transform(train_xs)
scaler.fit(train_xs)
scaler.transform(test_xs)
# Out:
# array([[-0.15324839],
#        [ 0.69813154],
#        [ 0.35757957],
#        [-1.1749043 ],
#        [-0.32352437],
#        [ 0.86840753],
#        [-1.68573226],
#        [-0.49380036],
#        [-1.00462832],
#        [ 1.54951147]])
