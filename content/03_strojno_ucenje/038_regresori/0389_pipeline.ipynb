# %% [markdown]
# # Pipelines

# %%
from sklearn import linear_model, pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
xs = np.linspace(-5, 10, 20)
ys = 3 * xs + 2 * np.random.uniform(20, 40, 20)
(train_xs, test_xs, train_ys, test_ys)= train_test_split(xs.reshape(-1, 1), ys.reshape(-1, 1),test_size=.5)
scaler = StandardScaler()
lr = linear_model.LinearRegression()
std_lr_pipe = pipeline.make_pipeline(scaler, lr)
std_lr_pipe.fit(train_xs, train_ys).predict(test_xs)
# Out:
# array([[50.5896274 ],
#        [55.12747276],
#        [86.89239031],
#        [80.08562226],
#        [68.74100885],
#        [73.27885422],
#        [93.69915835],
#        [61.93424081],
#        [59.66531813],
#        [75.5477769 ]])
