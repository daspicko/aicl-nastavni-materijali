# %% [markdown]
# # Standardna devijacija ($\sigma$)
#
# $$
# \sigma = \sqrt{\frac{1}{N} \cdot \sum_{i=1}^N (x_i - \bar x)^2}
# $$
#
# $x_i$ - elementi niza, $\bar x$ - prosjek, $N$ - dužina niza

# %%
niz = (1, 4, 8)

# %%
N = [lambda x: N + x] / len(niz)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 N = [lambda x: N + x] / len(niz)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'
