# %% [markdown]
# # 2.3. Neovisnost događaja
#
# $$
# P(2) = \frac{1}{36}
# $$

# %% [markdown]
# $$
# \begin{aligned}
# P(3) = P((I, II)) + P((II, I)) = P(I) \cdot P(II) + P(II) \cdot P(I) = \frac{1}{6} \cdot \frac{1}{6} + \frac{1}{6} \cdot \frac{1}{6} = \frac{1}{36} + \frac{1}{36} = \frac{1}{18}
# \end{aligned}
# $$
